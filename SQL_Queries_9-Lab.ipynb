# %%
import pandas as pd
import numpy as np

import pymysql
from sqlalchemy import create_engine

import getpass  # To get the password without showing the input

# %%
password = getpass.getpass()
# Out:
# ········

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/bank'
#c = connection_string.cursor()
engine = create_engine(connection_string)

# %%
#QUESTION 1
actors_lname = pd.read_sql_query('SELECT COUNT(DISTINCT last_name) AS distinct_names FROM sakila.actor;', engine)
#SELECT COUNT(DISTINCT last_name) AS distinct_names FROM sakila.actor;
#actors_lname['distinct_names'][0]
actors_lname
# Out:
#    distinct_names
# 0             121

# %%
#QUESTION 2
new_data = pd.read_sql_query("SELECT *,CASE WHEN dayofweek(rental_date) > 5 THEN 'weekend' ELSE 'weekday' END AS day_type  FROM sakila.rental;", engine)                         
new_data.head(10)
# Out:
#    rental_id         rental_date  inventory_id  customer_id  \
# 0          1 2005-05-24 22:53:30           367          130
# 1          2 2005-05-24 22:54:33          1525          459
# 2          3 2005-05-24 23:03:39          1711          408
# 3          4 2005-05-24 23:04:41          2452          333
# 4          5 2005-05-24 23:05:21          2079          222
# 5          6 2005-05-24 23:08:07          2792          549
# 6          7 2005-05-24 23:11:53          3995          269
# 7          8 2005-05-24 23:31:46          2346          239
# 8          9 2005-05-25 00:00:40          2580          126
# 9         10 2005-05-25 00:02:21          1824          399
#
#           return_date  staff_id         last_update day_type
# 0 2005-05-26 22:04:30         1 2006-02-15 21:30:53  weekday
# 1 2005-05-28 19:40:33         1 2006-02-15 21:30:53  weekday
# 2 2005-06-01 22:12:39         1 2006-02-15 21:30:53  weekday
# ...

# %%
#QUESTION 3
data1 = pd.read_sql_query("SELECT * FROM sakila.film WHERE title LIKE '%%ARMAGEDDON%%';", engine)
# https://stackoverflow.com/questions/11695801/python-valueerror-unsupported-format-character-0x27-at-index-1
data1.head()
# Out:
#    film_id                  title  \
# 0       39        ARMAGEDDON LOST
# 1      507    LADYBUGS ARMAGEDDON
# 2      571       METAL ARMAGEDDON
# 3      598    MOSQUITO ARMAGEDDON
# 4      838  STAGECOACH ARMAGEDDON
#
#                                          description  release_year  \
# 0  A Fast-Paced Tale of a Boat And a Teacher who ...          2006
# 1  A Fateful Reflection of a Dog And a Mad Scient...          2006
# 2  A Thrilling Display of a Lumberjack And a Croc...          2006
# 3  A Thoughtful Character Study of a Waitress And...          2006
# 4  A Touching Display of a Pioneer And a Butler w...          2006
#
#    language_id original_language_id  rental_duration  rental_rate  length  \
# 0            1                 None                5         0.99      99
# 1            1                 None                4         0.99     113
# 2            1                 None                6         2.99     161
# ...

# %%
#QUESTION 4
film_len = pd.read_sql_query("SELECT film_id, title,length FROM sakila.film ORDER BY length DESC LIMIT 10;", engine)
film_len
# Out:
#    film_id               title  length
# 0      212      DARN FORRESTER     185
# 1      872   SWEET BROTHERHOOD     185
# 2      426           HOME PITY     185
# 3      817  SOLDIERS EVOLUTION     185
# 4      349         GANGS PRIDE     185
# 5      991        WORST BANGER     185
# 6      609       MUSCLE BRIGHT     185
# 7      141       CHICAGO NORTH     185
# 8      690        POND SEATTLE     185
# 9      182      CONTROL ANTHEM     185

# %%
#QUESTION 5
behind_scene = pd.read_sql_query("SELECT COUNT(*) FROM sakila.film WHERE special_features LIKE '%%Behind the Scenes%%';", engine)
behind_scene
# Out:
#    COUNT(*)
# 0       538

# %%
# QUESTION 6
avg_len = pd.read_sql_query("""SELECT film_id, title, AVG(length) AS mov_len FROM sakila.film
GROUP BY rating HAVING AVG(length)>120;""", engine)
avg_len
# Out:
#    film_id            title   mov_len
# 0        7  AIRPLANE SIERRA  120.4439

# %%
#QUESTION 7
film_rank = pd.read_sql_query("""SELECT title, length, rating FROM sakila.film
WHERE length <>0 OR NULL ORDER BY length DESC""", engine)
film_rank
# Out:
#                    title  length rating
# 0              HOME PITY     185      R
# 1            GANGS PRIDE     185  PG-13
# 2         CONTROL ANTHEM     185      G
# 3         DARN FORRESTER     185      G
# 4          MUSCLE BRIGHT     185      G
# ..                   ...     ...    ...
# 995            IRON MOON      46     PG
# 996         ALIEN CENTER      46  NC-17
# 997     LABYRINTH LEAGUE      46  PG-13
# 998        KWAI HOMEWARD      46  PG-13
# 999  RIDGEMONT SUBMARINE      46  PG-13
#
# [1000 rows x 3 columns]
